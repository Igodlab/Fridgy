# %% [markdown]
# # Fridgy receit recognition
# This framework gives the functionality of getting the list of all purchased item into the app just by scanning.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

# %%
## load some receits data
data_path = os.path.join("./","data-receits")
data_path+" potito"
# Out:
# './data-receits potito'

# %%
ii = plt.imread(os.path.join(data_path, "veggie-grocery-receipt_orig.jpeg"))

# %%
plt.imshow(ii)
plt.axis("off")
# Out:
# (-0.5, 464.5, 552.5, -0.5)

# %%
np.shape(ii)
# Out:
# (553, 465, 3)
